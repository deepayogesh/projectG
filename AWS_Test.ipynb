# %%
# Import Dependencies
import config
import pandas as pd
import psycopg2
#from sqlalchemy import create_engine

# %%
# db_config
#db_database="postgres"
#db_user="postgres"
#db_host="database-1.cfp4cgpvvsmv.us-east-2.rds.amazonaws.com"
#db_password="g-mvsProject"
#db_port="5432"

# %%
# Configure AWS RDS Connection:

engine = psycopg2.connect (
        database=config.db_database,
        user=config.db_user,
        password=config.db_password,
        host=config.db_host,
        port=config.db_port
        )

# %%
# If RDS Connection was successful
# declare a cursor object from the connection

if engine != None:
    cursor = engine.cursor()
    print("Database connected Successfully!")
    print(f"Cursor object: {cursor}\n")
else:
    print_psycopg2_exception(err)
# Out:
# Database connected Successfully!
# Cursor object: <cursor object at 0x00000000055F5208; closed: 0>

# %%
# Read in Data from Database

import_query = "SELECT * FROM G_MVS_TITLE_BASICS"

data = pd.read_sql(import_query, engine)

# %%
# Check Results

data
# Out:
#            tconst titletype  \
# 0       tt0000574     movie
# 1       tt0000591     movie
# 2       tt0000679     movie
# 3       tt0001184     movie
# 4       tt0001258     movie
# ...           ...       ...
# 338961  tt9916362     movie
# 338962  tt9916538     movie
# 338963  tt9916622     movie
# 338964  tt9916680     movie
# 338965  tt9916754     movie
#
#                                              primarytitle  \
# 0                             The Story of the Kelly Gang
# 1                                        The Prodigal Son
# 2                          The Fairylogue and Radio-Plays
# 3                                 Don Juan de Serrallonga
# 4                                   The White Slave Trade
# ...                                                   ...
# 338961                                              Coven
# 338962                                Kuambil Lagi Hatiku
# 338963       Rodolpho TeÃ³philo - O Legado de um Pioneiro
# ...
